# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2,3]
b = [4,5,6]
plt.plot(a,b)

# %%
plt.show() # 生成一个基本的图

# %%
# %matplotlib inline

# %%
# %timeit np.arange(10)
# Out:
# 580 ns ± 27.5 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
c = [10,8,6]
d= [1,8,3]
plt.plot(a,b,'r--',c,d, 'b*')
# Out:
# [<matplotlib.lines.Line2D at 0x1f867cb8820>,
#  <matplotlib.lines.Line2D at 0x1f867cb8850>]

# %%
t = np.arange(0.0,2.0,0.1)

# %%
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s.size
# Out:
# 20

# %%
plt.plot(t,s, 'r--', t*2, s, '--')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
