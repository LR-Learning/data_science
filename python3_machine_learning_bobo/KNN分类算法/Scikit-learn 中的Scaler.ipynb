# %%
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardScaler = StandardScaler()
standardScaler.fit(X_train)
# Out:
# StandardScaler()

# %%
standardScaler.mean_
# Out:
# array([5.83416667, 3.07666667, 3.71583333, 1.18333333])

# %%
standardScaler.scale_ # 描述数据分布范围
# Out:
# array([0.82527731, 0.45013578, 1.76266823, 0.75424723])

# %%
X_train = standardScaler.transform(X_train) # 对数据进行归一化

# %%
X_train
# Out:
# array([[-1.13194275,  0.05183621, -1.25709041, -1.43631065],
#        [-0.52608579,  0.71830178, -1.14362606, -1.30372813],
#        [-1.49545692,  0.05183621, -1.25709041, -1.30372813],
#        [ 0.20094256, -1.9475605 ,  0.72853566,  0.41984465],
#        [ 0.32211395, -0.61462936,  0.55833914,  0.02209709],
#        [ 1.0491423 , -0.17031898,  0.72853566,  0.68500969],
#        [-0.4049144 , -1.50325012,  0.04774958, -0.11048543],
#        [-0.16257162,  1.60692254, -1.14362606, -1.17114561],
#        [ 0.20094256,  0.71830178,  0.44487479,  0.55242717],
#        [-0.4049144 , -1.05893974,  0.38814262,  0.02209709],
#        [ 0.44328534, -0.39247417,  0.33141045,  0.15467961],
#        [-0.88959997,  1.60692254, -1.03016172, -1.03856308],
#        [ 0.32211395, -0.61462936,  0.16121393,  0.15467961],
#        [-0.04140023, -0.83678455,  0.2179461 , -0.24306796],
#        [-0.52608579,  0.71830178, -1.25709041, -1.03856308],
#        [ 1.17031369, -0.17031898,  1.01219653,  1.21533978],
#        [ 2.13968482, -0.17031898,  1.63625044,  1.21533978],
#        [ 0.56445673, -1.28109493,  0.72853566,  0.95017474],
#        [-0.16257162,  2.93985368, -1.25709041, -1.03856308],
#        [-1.01077136,  0.49614659, -1.31382258, -1.30372813],
#        [ 0.44328534, -1.9475605 ,  0.44487479,  0.41984465],
#        [ 1.77617065, -0.39247417,  1.46605392,  0.81759222],
#        [ 0.20094256, -1.9475605 ,  0.16121393, -0.24306796],
#        [ 0.20094256, -0.17031898,  0.61507131,  0.81759222],
#        [-1.37428553,  0.2739914 , -1.20035824, -1.30372813],
#        [-0.4049144 , -1.28109493,  0.16121393,  0.15467961],
#        [ 0.07977117, -0.17031898,  0.78526783,  0.81759222],
#        [-1.8589711 , -0.17031898, -1.4840191 , -1.43631065],
#        [-0.4049144 ,  0.94045697, -1.37055476, -1.30372813],
#        [-1.25311414,  0.05183621, -1.20035824, -1.30372813],
#        [-0.52608579,  1.38476735, -1.25709041, -1.30372813],
#        [ 1.53382786, -0.17031898,  1.23912522,  1.21533978],
#        [-1.01077136,  1.16261216, -1.31382258, -1.30372813],
#        [-1.49545692,  0.2739914 , -1.31382258, -1.30372813],
#        [ 2.50319899,  1.60692254,  1.52278609,  1.08275726],
#        [-0.4049144 ,  2.4955433 , -1.31382258, -1.30372813],
#        [-0.16257162, -0.61462936,  0.2179461 ,  0.15467961],
#        [ 0.32211395, -0.39247417,  0.55833914,  0.28726213],
#        [-1.01077136,  0.71830178, -1.20035824, -1.03856308],
#        [ 2.26085621, -0.61462936,  1.69298261,  1.08275726],
#        [ 0.68562812,  0.2739914 ,  0.89873218,  1.48050482],
#        [ 1.0491423 , -0.17031898,  0.84200001,  1.48050482],
#        [-0.76842857,  0.71830178, -1.31382258, -1.30372813],
#        [-0.4049144 , -1.50325012, -0.00898259, -0.24306796],
#        [-1.01077136,  0.2739914 , -1.42728693, -1.30372813],
#        [ 0.20094256, -0.39247417,  0.44487479,  0.41984465],
#        [ 0.20094256, -0.83678455,  0.78526783,  0.55242717],
#        [ 0.56445673,  0.71830178,  1.0689287 ,  1.61308734],
#        [-0.16257162, -0.17031898,  0.27467827,  0.02209709],
#        [ 2.26085621, -0.17031898,  1.35258957,  1.48050482],
#        [-1.73779971, -0.39247417, -1.31382258, -1.30372813],
#        [-0.4049144 , -1.72540531,  0.16121393,  0.15467961],
#        [ 1.0491423 ,  0.49614659,  1.12566087,  1.74566987],
#        [ 1.65499925,  1.16261216,  1.35258957,  1.74566987],
#        [ 1.65499925,  0.2739914 ,  1.29585739,  0.81759222],
#        [ 0.56445673, -0.39247417,  1.0689287 ,  0.81759222],
#        [-0.28374301, -0.39247417, -0.06571477,  0.15467961],
#        [-0.04140023,  2.05123292, -1.42728693, -1.30372813],
#        [-0.04140023, -0.83678455,  0.78526783,  0.95017474],
#        [ 0.56445673,  0.49614659,  0.55833914,  0.55242717],
#        [ 0.68562812, -0.39247417,  0.33141045,  0.15467961],
#        [ 0.68562812,  0.05183621,  1.01219653,  0.81759222],
#        [ 0.68562812, -0.61462936,  1.0689287 ,  1.21533978],
#        [-1.13194275, -1.28109493,  0.44487479,  0.68500969],
#        [ 0.07977117, -0.17031898,  0.27467827,  0.41984465],
#        [ 1.29148508,  0.05183621,  0.78526783,  1.48050482],
#        [-0.88959997,  1.60692254, -1.20035824, -1.30372813],
#        [ 1.17031369,  0.2739914 ,  1.23912522,  1.48050482],
#        [ 2.26085621,  1.60692254,  1.69298261,  1.3479223 ],
#        [-1.01077136, -0.17031898, -1.20035824, -1.30372813],
#        [ 0.80679951, -0.17031898,  0.84200001,  1.08275726],
#        [-1.49545692,  0.71830178, -1.31382258, -1.17114561],
#        [ 1.0491423 ,  0.49614659,  1.12566087,  1.21533978],
#        [-1.49545692,  1.16261216, -1.54075128, -1.30372813],
#        [-0.76842857,  2.27338811, -1.25709041, -1.43631065],
#        [-0.88959997,  0.49614659, -1.14362606, -0.90598056],
#        [ 0.32211395, -0.17031898,  0.50160697,  0.28726213],
#        [ 1.29148508,  0.05183621,  0.95546435,  1.21533978],
#        [ 0.56445673, -0.61462936,  0.78526783,  0.41984465],
#        [-0.88959997,  0.94045697, -1.31382258, -1.17114561],
#        [-1.01077136,  0.94045697, -1.20035824, -0.77339804],
#        [-0.04140023, -0.83678455,  0.78526783,  0.95017474],
#        [-1.73779971,  0.2739914 , -1.37055476, -1.30372813],
#        [-0.16257162, -1.05893974, -0.12244694, -0.24306796],
#        [ 0.80679951, -0.17031898,  1.01219653,  0.81759222],
#        [ 1.0491423 ,  0.05183621,  0.55833914,  0.41984465],
#        [-0.28374301, -0.17031898,  0.44487479,  0.41984465],
#        [ 0.92797091, -0.17031898,  0.38814262,  0.28726213],
#        [-0.04140023, -0.83678455,  0.10448175,  0.02209709],
#        [-1.61662831, -1.72540531, -1.37055476, -1.17114561],
#        [ 0.80679951, -0.61462936,  0.50160697,  0.41984465],
#        [-0.52608579,  1.82907773, -1.37055476, -1.03856308],
#        [-1.73779971, -0.17031898, -1.37055476, -1.30372813],
#        [ 1.41265647,  0.2739914 ,  0.55833914,  0.28726213],
#        [-0.52608579, -0.17031898,  0.44487479,  0.41984465],
#        [ 0.44328534, -0.61462936,  0.61507131,  0.81759222],
#        [-0.16257162, -0.39247417,  0.27467827,  0.15467961],
#        [ 1.0491423 ,  0.05183621,  0.38814262,  0.28726213],
#        [-0.88959997,  1.60692254, -1.25709041, -1.17114561],
#        [ 1.65499925, -0.17031898,  1.18239305,  0.55242717],
#        [-0.88959997,  0.94045697, -1.31382258, -1.30372813],
#        [-0.28374301, -0.61462936,  0.67180349,  1.08275726],
#        [-1.01077136, -2.39187087, -0.12244694, -0.24306796],
#        [-0.16257162, -1.28109493,  0.72853566,  1.08275726],
#        [-0.52608579,  1.82907773, -1.14362606, -1.03856308],
#        [-1.13194275, -1.50325012, -0.23591129, -0.24306796],
#        [-0.16257162, -0.61462936,  0.44487479,  0.15467961],
#        [-1.13194275,  0.05183621, -1.25709041, -1.30372813],
#        [-0.64725718,  1.38476735, -1.25709041, -1.30372813],
#        [ 0.68562812,  0.2739914 ,  0.44487479,  0.41984465],
#        [-0.28374301, -1.28109493,  0.10448175, -0.11048543],
#        [-1.01077136,  0.71830178, -1.25709041, -1.30372813],
#        [-1.01077136, -1.72540531, -0.23591129, -0.24306796],
#        [-1.37428553,  0.2739914 , -1.37055476, -1.30372813],
#        [ 0.56445673,  0.49614659,  1.29585739,  1.74566987],
#        [ 0.56445673, -0.83678455,  0.67180349,  0.81759222],
#        [-1.01077136,  0.94045697, -1.37055476, -1.17114561],
#        [ 1.0491423 ,  0.05183621,  1.0689287 ,  1.61308734],
#        [ 1.0491423 , -1.28109493,  1.18239305,  0.81759222],
#        [ 0.32211395, -0.17031898,  0.67180349,  0.81759222]])

# %%
X_test_standardScaler = standardScaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.score(X_test_standardScaler, y_test)
# Out:
# 0.9
